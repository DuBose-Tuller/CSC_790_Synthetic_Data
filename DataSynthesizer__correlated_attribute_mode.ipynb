# %% [markdown]
# # DataSynthesizer Usage (correlated attribute mode)
#
# > This is a quick demo to use DataSynthesizer in correlated attribute mode.
#
# ### Step 1 import packages

# %%
# !pip install DataSynthesizer jupyter ipython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: DataSynthesizer in /home/sahau24/.local/lib/python3.11/site-packages (0.1.13)
# Requirement already satisfied: jupyter in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: ipython in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (8.21.0)
# Requirement already satisfied: numpy>=1.18.5 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from DataSynthesizer) (1.26.4)
# Requirement already satisfied: pandas>=1.0.5 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from DataSynthesizer) (2.2.0)
# Requirement already satisfied: scikit-learn>=0.23.1 in /home/sahau24/.local/lib/python3.11/site-packages (from DataSynthesizer) (1.5.2)
# Requirement already satisfied: matplotlib>=3.2.2 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from DataSynthesizer) (3.8.3)
# Requirement already satisfied: seaborn>=0.10.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from DataSynthesizer) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/sahau24/.local/lib/python3.11/site-packages (from DataSynthesizer) (2.9.0.post0)
# Requirement already satisfied: notebook in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter) (7.1.0)
# Requirement already satisfied: qtconsole in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter) (5.5.1)
# Requirement already satisfied: jupyter-console in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter) (7.16.0)
# Requirement already satisfied: ipykernel in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter) (6.29.2)
# Requirement already satisfied: ipywidgets in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter) (8.1.2)
# Requirement already satisfied: decorator in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipython) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipython) (2.17.2)
# Requirement already satisfied: stack-data in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipython) (5.14.1)
# Requirement already satisfied: pexpect>4.3 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: wcwidth in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sahau24/.local/lib/python3.11/site-packages (from matplotlib>=3.2.2->DataSynthesizer) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/sahau24/.local/lib/python3.11/site-packages (from matplotlib>=3.2.2->DataSynthesizer) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sahau24/.local/lib/python3.11/site-packages (from matplotlib>=3.2.2->DataSynthesizer) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sahau24/.local/lib/python3.11/site-packages (from matplotlib>=3.2.2->DataSynthesizer) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/sahau24/.local/lib/python3.11/site-packages (from matplotlib>=3.2.2->DataSynthesizer) (24.2)
# Requirement already satisfied: pillow>=8 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from matplotlib>=3.2.2->DataSynthesizer) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sahau24/.local/lib/python3.11/site-packages (from matplotlib>=3.2.2->DataSynthesizer) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from pandas>=1.0.5->DataSynthesizer) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from pandas>=1.0.5->DataSynthesizer) (2024.1)
# Requirement already satisfied: ptyprocess>=0.5 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/sahau24/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.1->DataSynthesizer) (1.17.0)
# Requirement already satisfied: scipy>=1.6.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from scikit-learn>=0.23.1->DataSynthesizer) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from scikit-learn>=0.23.1->DataSynthesizer) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/sahau24/.local/lib/python3.11/site-packages (from scikit-learn>=0.23.1->DataSynthesizer) (3.6.0)
# Requirement already satisfied: comm>=0.1.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipykernel->jupyter) (1.8.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipykernel->jupyter) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipykernel->jupyter) (5.7.1)
# Requirement already satisfied: nest-asyncio in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipykernel->jupyter) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipykernel->jupyter) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipykernel->jupyter) (6.4)
# Requirement already satisfied: platformdirs>=2.5 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.2.0)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipywidgets->jupyter) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from ipywidgets->jupyter) (3.0.10)
# Requirement already satisfied: beautifulsoup4 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (3.1.3)
# Requirement already satisfied: jupyterlab-pygments in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: webencodings in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: fastjsonschema in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert->jupyter) (4.21.1)
# Requirement already satisfied: attrs>=22.2.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (0.18.0)
# Requirement already satisfied: soupsieve>1.2 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from notebook->jupyter) (2.12.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from notebook->jupyter) (2.25.3)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from notebook->jupyter) (4.1.1)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from notebook->jupyter) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.2.0)
# Requirement already satisfied: argon2-cffi in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.5.2)
# Requirement already satisfied: overrides in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.0)
# Requirement already satisfied: websocket-client in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter) (2.2.2)
# Requirement already satisfied: babel>=2.10 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.14)
# Requirement already satisfied: requests>=2.31 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: certifi in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter) (1.0.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter) (0.14.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.4)
# Requirement already satisfied: uri-template in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.2.0)
# Requirement already satisfied: argon2-cffi-bindings in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.8.19.20240106)
# Requirement already satisfied: qtpy>=2.4.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from stack-data->ipython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from stack-data->ipython) (2.4.1)
# Requirement already satisfied: pure-eval in /deac/opt/rocky9-noarch/python/3.11.8/lib/python3.11/site-packages (from stack-data->ipython) (0.2.2)

# %%
from DataSynthesizer.DataDescriber import DataDescriber
from DataSynthesizer.DataGenerator import DataGenerator
from DataSynthesizer.ModelInspector import ModelInspector
from DataSynthesizer.lib.utils import read_json_file, display_bayesian_network

import pandas as pd

# %% [markdown]
# ### Step 2 user-defined parameteres

# %%
# input dataset
input_data = '/home/sahau24/csc790project/CSC_790_Synthetic_Data/Urmi.csv'
# location of two output files
mode = 'correlated_attribute_mode'
description_file = f'/home/sahau24/csc790project/CSC_790_Synthetic_Data/description.json'
synthetic_data = f'/home/sahau24/csc790project/CSC_790_Synthetic_Data/synthetic_data.csv'

# %%
# An attribute is categorical if its domain size is less than this threshold.
# Here modify the threshold to adapt to the domain size of "education" (which is 14 in input dataset).
threshold_value = 20

# specify categorical attributes
categorical_attributes = {'education': True}

# specify which attributes are candidate keys of input dataset.
candidate_keys = {'ssn': True}

# A parameter in Differential Privacy. It roughly means that removing a row in the input dataset will not 
# change the probability of getting the same output more than a multiplicative difference of exp(epsilon).
# Increase epsilon value to reduce the injected noises. Set epsilon=0 to turn off differential privacy.
epsilon = 1

# The maximum number of parents in Bayesian network, i.e., the maximum number of incoming edges.
degree_of_bayesian_network = 2

# Number of tuples generated in synthetic dataset.
num_tuples_to_generate = 1000 # Here 32561 is the same as input dataset, but it can be set to another number.

# %% [markdown]
# ### Step 3 DataDescriber
#
# 1. Instantiate a DataDescriber.
# 2. Compute the statistics of the dataset.
# 3. Save dataset description to a file on local machine.

# %%
describer = DataDescriber(category_threshold=threshold_value)
describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                        epsilon=epsilon, 
                                                        k=degree_of_bayesian_network,
                                                        attribute_to_is_categorical=categorical_attributes,
                                                        attribute_to_is_candidate_key=candidate_keys)
describer.save_dataset_description_to_file(description_file)
# Out:
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute body_mass_g
# Adding attribute culmen_depth_mm
# Adding attribute flipper_length_mm
# Adding attribute culmen_length_mm
# Adding attribute species
# Adding attribute island
# ========================== BN constructed ==========================

# %%
display_bayesian_network(describer.bayesian_network)
# Out:
# Constructed Bayesian network:
#     body_mass_g       has parents ['sex'].
#     culmen_depth_mm   has parents ['body_mass_g', 'sex'].
#     flipper_length_mm has parents ['culmen_depth_mm', 'body_mass_g'].
#     culmen_length_mm  has parents ['flipper_length_mm', 'body_mass_g'].
#     species           has parents ['culmen_length_mm', 'culmen_depth_mm'].
#     island            has parents ['culmen_length_mm', 'culmen_depth_mm'].

# %% [markdown]
# ### Step 4 generate synthetic dataset
#
# 1. Instantiate a DataGenerator.
# 2. Generate a synthetic dataset.
# 3. Save it to local machine.

# %%
generator = DataGenerator()
generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
generator.save_synthetic_data(synthetic_data)

# %% [markdown]
# ### Step 5 compare the statistics of input and sythetic data (optional)
#
# The synthetic data is already saved in a file by step 4. The ModelInspector is for a quick test on the similarity between input and synthetic datasets.
#
# #### 5.1 instantiate a ModelInspector.
#
# It needs input dataset, synthetic dataset, and attribute description.

# %%
# Read both datasets using Pandas.
input_df = pd.read_csv(input_data, skipinitialspace=True)
synthetic_df = pd.read_csv(synthetic_data)
# Read attribute description from the dataset description file.
attribute_description = read_json_file(description_file)['attribute_description']

inspector = ModelInspector(input_df, synthetic_df, attribute_description)

# %% [markdown]
# #### 5.2 compare histograms between input and synthetic datasets.

# %%
for attribute in synthetic_df.columns:
    inspector.compare_histograms(attribute)

# %% [markdown]
# #### 5.3 compare pairwise mutual information

# %%
inspector.mutual_information_heatmap()
